# %% [markdown]
# #Лабораторна робота2
#
# ## Завдання
#
#
# <ol>
#   <li>Обрати досліджуваний напрямок у галузі ІТ (бажано в рамках майбутньої магістерської роботи)</li>
#   <li>Підібрати наукові статті за обраним напрямком англійською мовою, з яких вилучити 100 речень, які найбільш відповідають зазначеному напрямку</li>
#   <li>Створити та зберегти у .csv файл pandas DataFrame з обраних речень із указанням в окремому ствопчику назви напрямку (ця назва має бути однаковою для усіх речень)</li>
#   <li>Здійснити підготовку набору даних до подальшого моделювання (tokenization&embedding, train_test_split)</li>
#   <li>Відповіді оформити .ipynb, .csv, .pdf документами</li>
#   <li>Викласти у зазначений репозіторій GitHub в окремій папці з назвою Lab2 де мають бути .ipynb файл та необхідні файли з даними та статями</li>
#   <li>Підготуватися до захисту та доповіді результатів (1 доповідь від команди)</li>
# </ol>
